# %%
# %matplotlib inline
from skimage import novice, data, io, exposure
from datetime import datetime
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import dicom

ConstPixelDims = (int(RefDs.Rows), int(RefDs.Columns))
ArrayDicom = np.zeros(ConstPixelDims, dtype=RefDs.pixel_array.dtype)
ds = dicom.read_file('IM_0012.dcm')
ArrayDicom[:,:]=ds.pixel_array

#plt.figure()
fig=plt.figure(figsize=(10, 10), dpi= 80, facecolor='w', edgecolor='k')
plt.axes().set_aspect('equal') #this makes the image square
plt.set_cmap(plt.gray()) #grayscale
x=np.arange(RefDs.Rows)
y=np.arange(RefDs.Columns)

plt.pcolormesh(x, y, np.flipud(ArrayDicom[:, :]))
plt.axis([x.min(),x.max(),y.min(),y.max()])
# Out:
# [0, 255, 0, 255]

# %%
ConstPixelDims = (int(RefDs.Rows), int(RefDs.Columns))
ArrayDicom = np.zeros(ConstPixelDims, dtype=RefDs.pixel_array.dtype)
ds = dicom.read_file('IM_0013.dcm')
ArrayDicom[:,:]=ds.pixel_array

#plt.figure()
fig=plt.figure(figsize=(10, 10), dpi= 80, facecolor='w', edgecolor='k')
plt.axes().set_aspect('equal') #this makes the image square
plt.set_cmap(plt.gray()) #grayscale
x=np.arange(RefDs.Rows)
y=np.arange(RefDs.Columns)

plt.pcolormesh(x, y, np.flipud(ArrayDicom[:, :]))
plt.axis([x.min(),x.max(),y.min(),y.max()])
# Out:
# [0, 255, 0, 255]

# %%
ConstPixelDims = (int(RefDs.Rows), int(RefDs.Columns))
ArrayDicom = np.zeros(ConstPixelDims, dtype=RefDs.pixel_array.dtype)
ds = dicom.read_file('IM_0014.dcm')
ArrayDicom[:,:]=ds.pixel_array

#plt.figure()
fig=plt.figure(figsize=(10, 10), dpi= 80, facecolor='w', edgecolor='k')
plt.axes().set_aspect('equal') #this makes the image square
plt.set_cmap(plt.gray()) #grayscale
x=np.arange(RefDs.Rows)
y=np.arange(RefDs.Columns)

plt.pcolormesh(x, y, np.flipud(ArrayDicom[:, :]))
plt.axis([x.min(),x.max(),y.min(),y.max()])
# Out:
# [0, 255, 0, 255]

# %%
RefDs = dicom.read_file('IM_0012.dcm')
# Let's print all the Metadata here
print(RefDs)
# Out:
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'M_FFE', 'M', 'FFE']
# (0008, 0012) Instance Creation Date              DA: '20171115'
# (0008, 0013) Instance Creation Time              TM: '111930'
# (0008, 0014) Instance Creator UID                UI: 1.3.46.670589.11.34055.5
# (0008, 0016) SOP Class UID                       UI: MR Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.46.670589.11.34055.5.0.4164.2017111510391773025
# (0008, 0020) Study Date                          DA: '20171115'
# (0008, 0021) Series Date                         DA: '20171115'
# (0008, 0022) Acquisition Date                    DA: '20171115'
# (0008, 0023) Content Date                        DA: '20171115'
# (0008, 0030) Study Time                          TM: '102824'
# (0008, 0031) Series Time                         TM: '103832.39000'
# ...

# %% [markdown]
# You can browse through that Metadata and see all the information about this image. We can already easily find out this was a Magnetic Resonance Image made with a Philips Medical Systems.
#
# Let's answer the following questions with the Metadata:
# The type of MR sequence and the sequence parameters that were used to acquire the image(s)

# %%
print 'Acquistion matrix is ' +str(RefDs.AcquisitionMatrix)
print 'The image is ' +str(RefDs.Rows)+' x '+str(RefDs.Columns)+ ' pixels'
# Out:
# Acquistion matrix is [0, 256, 128, 0]
# The image is 256 x 256 pixels

# %%
print 'Imaging Frequency is ' +str(RefDs.ImagingFrequency)
# Out:
# Imaging Frequency is 127.753897
